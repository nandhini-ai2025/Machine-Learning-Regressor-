# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[["charges"]]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'criterion':['squared_error', 'absolute_error', 'friedman_mse'],
              'max_features':[None, 'sqrt', 'log2'],
              'splitter':['best', 'random']}

grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose = 3,  n_jobs = -1)

grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re = grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'absolute_error', 'max_features': None, 'splitter': 'random'}:

# %%
table = pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.014696      0.001942         0.005365        0.000467
# 1        0.009978      0.000760         0.007127        0.003844
# 2        0.010374      0.000757         0.005645        0.000720
# 3        0.009436      0.000361         0.005390        0.000670
# 4        0.011634      0.001500         0.004921        0.000395
# 5        0.008752      0.000886         0.005672        0.001066
# 6        0.051159      0.002303         0.004710        0.001130
# 7        0.039306      0.003506         0.005321        0.001218
# 8        0.032248      0.002111         0.004499        0.000683
# 9        0.025055      0.001493         0.005060        0.001021
# 10       0.032611      0.002683         0.005867        0.001004
# 11       0.025901      0.001262         0.007479        0.002086
# 12       0.011750      0.001058         0.004839        0.000607
# 13       0.009080      0.000657         0.004351        0.000204
# 14       0.011186      0.002213         0.005358        0.001496
# 15       0.009415      0.001246         0.005010        0.000658
# 16       0.010260      0.000472         0.005176        0.000249
# 17       0.008439      0.000640         0.005686        0.000775
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               None           best
# 1    squared_error               None         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6   absolute_error               None           best
# 7   absolute_error               None         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12    friedman_mse               None           best
# 13    friedman_mse               None         random
# 14    friedman_mse               sqrt           best
# 15    friedman_mse               sqrt         random
# 16    friedman_mse               log2           best
# 17    friedman_mse               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.716784
# 1   {'criterion': 'squared_error', 'max_features':...           0.694689
# 2   {'criterion': 'squared_error', 'max_features':...           0.668833
# 3   {'criterion': 'squared_error', 'max_features':...           0.549371
# 4   {'criterion': 'squared_error', 'max_features':...           0.752994
# 5   {'criterion': 'squared_error', 'max_features':...           0.688318
# 6   {'criterion': 'absolute_error', 'max_features'...           0.737193
# 7   {'criterion': 'absolute_error', 'max_features'...           0.714520
# 8   {'criterion': 'absolute_error', 'max_features'...           0.750260
# 9   {'criterion': 'absolute_error', 'max_features'...           0.719441
# 10  {'criterion': 'absolute_error', 'max_features'...           0.732153
# 11  {'criterion': 'absolute_error', 'max_features'...           0.680151
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.710546
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.726033
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.738625
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.701984
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.701589
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.640107
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.649598           0.726571           0.735562
# 1            0.581792           0.744357           0.726193
# 2            0.505019           0.710810           0.643573
# 3            0.540862           0.666508           0.722576
# 4            0.579312           0.707050           0.671884
# 5            0.499362           0.732833           0.703699
# 6            0.613776           0.719169           0.719426
# 7            0.616598           0.726770           0.756209
# 8            0.498802           0.723906           0.705540
# 9            0.636040           0.584861           0.705358
# 10           0.644420           0.737197           0.669394
# 11           0.494467           0.745205           0.692928
# 12           0.649288           0.732414           0.708556
# 13           0.596244           0.663918           0.660706
# 14           0.567477           0.728232           0.648718
# 15           0.567442           0.658578           0.661001
# 16           0.629997           0.547059           0.691753
# 17           0.578561           0.655434           0.590705
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.684445         0.702592        0.031626                4
# 1            0.732660         0.695938        0.059395                5
# 2            0.704489         0.646545        0.074864               15
# 3            0.640002         0.623864        0.069658               18
# 4            0.568152         0.655878        0.071923               14
# 5            0.696576         0.664158        0.083752               11
# 6            0.740954         0.706104        0.047019                3
# 7            0.767415         0.716302        0.053402                1
# 8            0.703529         0.676407        0.090375                8
# 9            0.710715         0.671283        0.052433               10
# 10           0.758795         0.708392        0.043699                2
# 11           0.681275         0.658805        0.085553               13
# 12           0.673609         0.694883        0.029571                6
# 13           0.721430         0.673666        0.047499                9
# 14           0.718403         0.680291        0.064618                7
# 15           0.595168         0.636835        0.048688               17
# 16           0.737196         0.661519        0.066845               12
# 17           0.736657         0.640293        0.056187               16

# %%
age_input = float(input("Age: "))
bmi_input = float(input("BMI: "))
children_input = int(input("Children: "))
sex_male_input = int(input("Sex Male - 1 for yes or 0 for no: "))
smoker_yes_input = int(input("Smoke Yes - 1 for yes or 0 for no: "))
# Out:
# Age:  66
# BMI:  20.000
# Children:  3
# Sex Male - 1 for yes or 0 for no:  0
# Smoke Yes - 1 for yes or 0 for no:  0

# %%
result = grid.predict([[age_input, bmi_input, children_input, sex_male_input, smoker_yes_input]])
print("result = {}".format(result))
# Out:
# result = [16455.70785]
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
