# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[["charges"]]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'criterion':['squared_error', 'absolute_error'],
              'max_features':[None, 'sqrt', 'log2'],
              'n_estimators':[10,100]}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3,  n_jobs = -1)
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re = grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 100}:

# %%
table = pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.099904      0.008700         0.009972        0.001236
# 1        0.853398      0.032283         0.035887        0.004022
# 2        0.077424      0.006550         0.010965        0.001306
# 3        0.587159      0.018646         0.039832        0.003829
# 4        0.065039      0.003768         0.008471        0.000685
# 5        0.565941      0.012934         0.034841        0.003432
# 6        0.302006      0.019050         0.007737        0.000307
# 7        2.830295      0.101251         0.032809        0.001715
# 8        0.163268      0.002912         0.007756        0.000676
# 9        1.779834      0.074643         0.035959        0.006828
# 10       0.174249      0.008475         0.009277        0.002938
# 11       1.422918      0.145598         0.024377        0.004352
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               None                  10
# 1    squared_error               None                 100
# 2    squared_error               sqrt                  10
# 3    squared_error               sqrt                 100
# 4    squared_error               log2                  10
# 5    squared_error               log2                 100
# 6   absolute_error               None                  10
# 7   absolute_error               None                 100
# 8   absolute_error               sqrt                  10
# 9   absolute_error               sqrt                 100
# 10  absolute_error               log2                  10
# 11  absolute_error               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.829848
# 1   {'criterion': 'squared_error', 'max_features':...           0.843623
# 2   {'criterion': 'squared_error', 'max_features':...           0.834658
# 3   {'criterion': 'squared_error', 'max_features':...           0.859400
# 4   {'criterion': 'squared_error', 'max_features':...           0.842029
# 5   {'criterion': 'squared_error', 'max_features':...           0.854476
# 6   {'criterion': 'absolute_error', 'max_features'...           0.816745
# 7   {'criterion': 'absolute_error', 'max_features'...           0.841800
# 8   {'criterion': 'absolute_error', 'max_features'...           0.845533
# 9   {'criterion': 'absolute_error', 'max_features'...           0.860360
# 10  {'criterion': 'absolute_error', 'max_features'...           0.837304
# 11  {'criterion': 'absolute_error', 'max_features'...           0.855975
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.756049           0.841285           0.811258
# 1            0.766102           0.859630           0.818581
# 2            0.764483           0.828941           0.813097
# 3            0.780734           0.860780           0.830130
# 4            0.757847           0.851714           0.817264
# 5            0.777566           0.866887           0.827822
# 6            0.763692           0.819091           0.815126
# 7            0.767219           0.853952           0.823906
# 8            0.755480           0.837570           0.818349
# 9            0.780022           0.852792           0.828305
# 10           0.751288           0.827936           0.829793
# 11           0.782818           0.852417           0.825714
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.818989         0.811486        0.029512               11
# 1            0.837582         0.825104        0.032294                5
# 2            0.837448         0.815726        0.026973                9
# 3            0.842051         0.834619        0.029249                1
# 4            0.824653         0.818701        0.032786                7
# 5            0.837603         0.832871        0.030759                2
# 6            0.812658         0.805462        0.020990               12
# 7            0.832913         0.823958        0.030058                6
# 8            0.824347         0.816256        0.031859                8
# 9            0.839328         0.832162        0.028304                4
# 10           0.829742         0.815213        0.032125               10
# 11           0.845112         0.832407        0.026912                3

# %%
age_input = float(input("Age: "))
bmi_input = float(input("BMI: "))
children_input = int(input("Children: "))
sex_male_input = int(input("Sex Male - 1 for yes or 0 for no: "))
smoker_yes_input = int(input("Smoke Yes - 1 for yes or 0 for no: "))
# Out:
# Age:  10
# BMI:  33.000
# Children:  4
# Sex Male - 1 for yes or 0 for no:  -1
# Smoke Yes - 1 for yes or 0 for no:  -1

# %%
result = grid.predict([[age_input, bmi_input, children_input, sex_male_input, smoker_yes_input]])
print("result = {}".format(result))
# Out:
# result = [7871.5681973]
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
